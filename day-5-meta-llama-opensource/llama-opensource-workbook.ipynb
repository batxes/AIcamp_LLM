# %% [markdown]
# # Ollama Workshop Guide for IDX
# ### Notes
# - We use an old ollama model, due to what is available in NIX store
# - The model used by ollama is also old, so it has poor quality in terms of language processing
# ## Prerequisites
# - IDX environment with Ollama pre-configured
#
# ## Setup Steps
#
# 1. Start Ollama server:
# ```bash
# ollama serve
# ```
#
# 2. Open a new terminal and pull the model:
# ```bash
# ollama pull gemma:2b
# ```
#
# 3. Test local inference:
# ```bash
# ollama run gemma:2b
# ```
#
# Exit the model interface:
# ```bash
# /exit
# ```
#
# ## Notes
# - Server terminal displays API interactions and logs
# - Browse available models at [ollama.com/search](https://ollama.com/search)
# - Ensure notebook uses lab_env virtual environment kernel

# %%
# Install requirements

# %pip install -r requirements.txt
# Out:
# Collecting llama-index-core (from -r requirements.txt (line 1))
#   Downloading llama_index_core-0.12.10.post1-py3-none-any.whl.metadata (2.5 kB)
# Collecting llama-index-llms-ollama (from -r requirements.txt (line 2))
#   Downloading llama_index_llms_ollama-0.5.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting llama-index-readers-file (from -r requirements.txt (line 3))
#   Downloading llama_index_readers_file-0.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting llama-index-embeddings-ollama (from -r requirements.txt (line 4))
#   Downloading llama_index_embeddings_ollama-0.5.0-py3-none-any.whl.metadata (684 bytes)
# Requirement already satisfied: PyYAML>=6.0.1 in /home/user/AIcamp_LLM/lab_env/lib/python3.11/site-packages (from llama-index-core->-r requirements.txt (line 1)) (6.0.2)
# Collecting SQLAlchemy>=1.4.49 (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core->-r requirements.txt (line 1))
#   Downloading SQLAlchemy-2.0.36-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.7 kB)
# Collecting aiohttp<4.0.0,>=3.8.6 (from llama-index-core->-r requirements.txt (line 1))
#   Downloading aiohttp-3.11.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting dataclasses-json (from llama-index-core->-r requirements.txt (line 1))
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting deprecated>=1.2.9.3 (from llama-index-core->-r requirements.txt (line 1))
#   Downloading Deprecated-1.2.15-py2.py3-none-any.whl.metadata (5.5 kB)
# Collecting dirtyjson<2.0.0,>=1.0.8 (from llama-index-core->-r requirements.txt (line 1))
#   Downloading dirtyjson-1.0.8-py3-none-any.whl.metadata (11 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from llama-index-core->-r requirements.txt (line 1))
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting fsspec>=2023.5.0 (from llama-index-core->-r requirements.txt (line 1))
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: httpx in /home/user/AIcamp_LLM/lab_env/lib/python3.11/site-packages (from llama-index-core->-r requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /home/user/AIcamp_LLM/lab_env/lib/python3.11/site-packages (from llama-index-core->-r requirements.txt (line 1)) (1.6.0)
# Collecting networkx>=3.0 (from llama-index-core->-r requirements.txt (line 1))
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting nltk>3.8.1 (from llama-index-core->-r requirements.txt (line 1))
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting numpy (from llama-index-core->-r requirements.txt (line 1))
#   Downloading numpy-2.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: pillow>=9.0.0 in /home/user/AIcamp_LLM/lab_env/lib/python3.11/site-packages (from llama-index-core->-r requirements.txt (line 1)) (11.0.0)
# Requirement already satisfied: pydantic>=2.8.0 in /home/user/AIcamp_LLM/lab_env/lib/python3.11/site-packages (from llama-index-core->-r requirements.txt (line 1)) (2.10.4)
# Requirement already satisfied: requests>=2.31.0 in /home/user/AIcamp_LLM/lab_env/lib/python3.11/site-packages (from llama-index-core->-r requirements.txt (line 1)) (2.32.3)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.2.0 (from llama-index-core->-r requirements.txt (line 1))
#   Downloading tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting tiktoken>=0.3.3 (from llama-index-core->-r requirements.txt (line 1))
#   Downloading tiktoken-0.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /home/user/AIcamp_LLM/lab_env/lib/python3.11/site-packages (from llama-index-core->-r requirements.txt (line 1)) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/user/AIcamp_LLM/lab_env/lib/python3.11/site-packages (from llama-index-core->-r requirements.txt (line 1)) (4.12.2)
# Collecting typing-inspect>=0.8.0 (from llama-index-core->-r requirements.txt (line 1))
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting wrapt (from llama-index-core->-r requirements.txt (line 1))
#   Downloading wrapt-1.17.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Collecting ollama>=0.4.3 (from llama-index-llms-ollama->-r requirements.txt (line 2))
#   Downloading ollama-0.4.5-py3-none-any.whl.metadata (4.7 kB)
# Collecting beautifulsoup4<5.0.0,>=4.12.3 (from llama-index-readers-file->-r requirements.txt (line 3))
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting pandas (from llama-index-readers-file->-r requirements.txt (line 3))
#   Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 8.4 MB/s eta 0:00:00
# Collecting pypdf<6.0.0,>=5.1.0 (from llama-index-readers-file->-r requirements.txt (line 3))
#   Downloading pypdf-5.1.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting striprtf<0.0.27,>=0.0.26 (from llama-index-readers-file->-r requirements.txt (line 3))
#   Downloading striprtf-0.0.26-py3-none-any.whl.metadata (2.1 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp<4.0.0,>=3.8.6->llama-index-core->-r requirements.txt (line 1))
#   Downloading aiohappyeyeballs-2.4.4-py3-none-any.whl.metadata (6.1 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.6->llama-index-core->-r requirements.txt (line 1))
#   Downloading aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.6->llama-index-core->-r requirements.txt (line 1))
#   Downloading attrs-24.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.6->llama-index-core->-r requirements.txt (line 1))
#   Downloading frozenlist-1.5.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.6->llama-index-core->-r requirements.txt (line 1))
#   Downloading multidict-6.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.6->llama-index-core->-r requirements.txt (line 1))
#   Downloading propcache-0.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.2 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.6->llama-index-core->-r requirements.txt (line 1))
#   Downloading yarl-1.18.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.2/69.2 kB 6.4 MB/s eta 0:00:00
# Collecting soupsieve>1.2 (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file->-r requirements.txt (line 3))
#   Downloading soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# Collecting click (from nltk>3.8.1->llama-index-core->-r requirements.txt (line 1))
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting joblib (from nltk>3.8.1->llama-index-core->-r requirements.txt (line 1))
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting regex>=2021.8.3 (from nltk>3.8.1->llama-index-core->-r requirements.txt (line 1))
#   Downloading regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 3.4 MB/s eta 0:00:00
# Collecting httpx (from llama-index-core->-r requirements.txt (line 1))
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: anyio in /home/user/AIcamp_LLM/lab_env/lib/python3.11/site-packages (from httpx->llama-index-core->-r requirements.txt (line 1)) (4.7.0)
# Requirement already satisfied: certifi in /home/user/AIcamp_LLM/lab_env/lib/python3.11/site-packages (from httpx->llama-index-core->-r requirements.txt (line 1)) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /home/user/AIcamp_LLM/lab_env/lib/python3.11/site-packages (from httpx->llama-index-core->-r requirements.txt (line 1)) (1.0.7)
# Requirement already satisfied: idna in /home/user/AIcamp_LLM/lab_env/lib/python3.11/site-packages (from httpx->llama-index-core->-r requirements.txt (line 1)) (3.10)
# Requirement already satisfied: sniffio in /home/user/AIcamp_LLM/lab_env/lib/python3.11/site-packages (from httpx->llama-index-core->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/user/AIcamp_LLM/lab_env/lib/python3.11/site-packages (from httpcore==1.*->httpx->llama-index-core->-r requirements.txt (line 1)) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/user/AIcamp_LLM/lab_env/lib/python3.11/site-packages (from pydantic>=2.8.0->llama-index-core->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/user/AIcamp_LLM/lab_env/lib/python3.11/site-packages (from pydantic>=2.8.0->llama-index-core->-r requirements.txt (line 1)) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/user/AIcamp_LLM/lab_env/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core->-r requirements.txt (line 1)) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/user/AIcamp_LLM/lab_env/lib/python3.11/site-packages (from requests>=2.31.0->llama-index-core->-r requirements.txt (line 1)) (2.3.0)
# Collecting greenlet!=0.4.17 (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core->-r requirements.txt (line 1))
#   Downloading greenlet-3.1.1-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect>=0.8.0->llama-index-core->-r requirements.txt (line 1))
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->llama-index-core->-r requirements.txt (line 1))
#   Downloading marshmallow-3.24.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/user/AIcamp_LLM/lab_env/lib/python3.11/site-packages (from pandas->llama-index-readers-file->-r requirements.txt (line 3)) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas->llama-index-readers-file->-r requirements.txt (line 3))
#   Downloading pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->llama-index-readers-file->-r requirements.txt (line 3))
#   Downloading tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: packaging>=17.0 in /home/user/AIcamp_LLM/lab_env/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core->-r requirements.txt (line 1)) (24.2)
# Requirement already satisfied: six>=1.5 in /home/user/AIcamp_LLM/lab_env/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-readers-file->-r requirements.txt (line 3)) (1.17.0)
# Downloading llama_index_core-0.12.10.post1-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 29.2 MB/s eta 0:00:0000:01
# Downloading llama_index_llms_ollama-0.5.0-py3-none-any.whl (6.7 kB)
# Downloading llama_index_readers_file-0.4.2-py3-none-any.whl (38 kB)
# Downloading llama_index_embeddings_ollama-0.5.0-py3-none-any.whl (2.6 kB)
# Downloading aiohttp-3.11.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 44.1 MB/s eta 0:00:00:00:01
# Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.9/147.9 kB 13.4 MB/s eta 0:00:00
# Downloading Deprecated-1.2.15-py2.py3-none-any.whl (9.9 kB)
# Downloading dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 16.5 MB/s eta 0:00:00
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 47.5 MB/s eta 0:00:00:00:01
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 58.4 MB/s eta 0:00:00
# Downloading ollama-0.4.5-py3-none-any.whl (13 kB)
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 7.9 MB/s eta 0:00:00
# Downloading pypdf-5.1.0-py3-none-any.whl (297 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 23.7 MB/s eta 0:00:00
# Downloading SQLAlchemy-2.0.36-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 59.4 MB/s eta 0:00:00:00:01
# Downloading striprtf-0.0.26-py3-none-any.whl (6.9 kB)
# Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Downloading tiktoken-0.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 38.0 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading wrapt-1.17.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.2/83.2 kB 8.4 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading numpy-2.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 46.5 MB/s eta 0:00:0000:0100:01m
# Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 54.6 MB/s eta 0:00:00:00:0100:01
# Downloading aiohappyeyeballs-2.4.4-py3-none-any.whl (14 kB)
# Downloading aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Downloading attrs-24.3.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.4/63.4 kB 6.4 MB/s eta 0:00:00
# Downloading frozenlist-1.5.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (274 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.9/274.9 kB 24.0 MB/s eta 0:00:00
# Downloading greenlet-3.1.1-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (602 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 602.4/602.4 kB 33.5 MB/s eta 0:00:00
# Downloading marshmallow-3.24.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 4.7 MB/s eta 0:00:00
# Downloading multidict-6.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.0/129.0 kB 12.6 MB/s eta 0:00:00
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading propcache-0.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.1/231.1 kB 19.4 MB/s eta 0:00:00
# Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 508.0/508.0 kB 31.3 MB/s eta 0:00:00
# Downloading regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (792 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 792.7/792.7 kB 44.6 MB/s eta 0:00:00
# Downloading soupsieve-2.6-py3-none-any.whl (36 kB)
# Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.6/346.6 kB 23.4 MB/s eta 0:00:00
# Downloading yarl-1.18.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (344 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 344.1/344.1 kB 22.0 MB/s eta 0:00:00
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 9.4 MB/s eta 0:00:00
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 24.1 MB/s eta 0:00:00
# Installing collected packages: striprtf, pytz, filetype, dirtyjson, wrapt, tzdata, tenacity, soupsieve, regex, pypdf, propcache, numpy, networkx, mypy-extensions, multidict, marshmallow, joblib, greenlet, fsspec, frozenlist, click, attrs, aiohappyeyeballs, yarl, typing-inspect, tiktoken, SQLAlchemy, pandas, nltk, httpx, deprecated, beautifulsoup4, aiosignal, ollama, dataclasses-json, aiohttp, llama-index-core, llama-index-readers-file, llama-index-llms-ollama, llama-index-embeddings-ollama
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.1
#     Uninstalling httpx-0.28.1:
#       Successfully uninstalled httpx-0.28.1
# Successfully installed SQLAlchemy-2.0.36 aiohappyeyeballs-2.4.4 aiohttp-3.11.11 aiosignal-1.3.2 attrs-24.3.0 beautifulsoup4-4.12.3 click-8.1.8 dataclasses-json-0.6.7 deprecated-1.2.15 dirtyjson-1.0.8 filetype-1.2.0 frozenlist-1.5.0 fsspec-2024.12.0 greenlet-3.1.1 httpx-0.27.2 joblib-1.4.2 llama-index-core-0.12.10.post1 llama-index-embeddings-ollama-0.5.0 llama-index-llms-ollama-0.5.0 llama-index-readers-file-0.4.2 marshmallow-3.24.0 multidict-6.1.0 mypy-extensions-1.0.0 networkx-3.4.2 nltk-3.9.1 numpy-2.2.1 ollama-0.4.5 pandas-2.2.3 propcache-0.2.1 pypdf-5.1.0 pytz-2024.2 regex-2024.11.6 soupsieve-2.6 striprtf-0.0.26 tenacity-9.0.0 tiktoken-0.8.0 typing-inspect-0.9.0 tzdata-2024.2 wrapt-1.17.0 yarl-1.18.3
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import libraries

import logging
from llama_index.core import SimpleDirectoryReader, Settings, VectorStoreIndex
from llama_index.embeddings.ollama import OllamaEmbedding
from llama_index.llms.ollama import Ollama

# %%
# Define a simple logging - so we can see some of the details printed out


def set_logging():
    # Create a logger instance
    logger = logging.getLogger(__name__)
    logger.setLevel(logging.DEBUG)  # Set the minimum logging level for the logger

    # Create a stream handler that outputs to the console
    stream_handler = logging.StreamHandler()
    stream_handler.setLevel(logging.INFO)  # Set the handler's level to INFO or DEBUG

    # Create a formatter to customize log output (optional, but recommended)
    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    stream_handler.setFormatter(formatter)

    # Add the stream handler to the logger
    logger.addHandler(stream_handler)



    #set up the global logger to have the same level and handler
    logging.basicConfig(level=logging.INFO, handlers=[stream_handler])

set_logging()

# %%
# 1. Load your data
logging.info("Loading documents...")
documents = SimpleDirectoryReader(input_dir="ollama-documents/").load_data()
logging.info(f"Loaded {len(documents)} documents.")
# Out:
# 2025-01-06 21:08:49,498 - root - INFO - Loading documents...
# 2025-01-06 21:08:49,989 - root - INFO - Loaded 1 documents.

# %%
# 2. Setup Ollama LLM
# we want the embeddings to synthesize document info!
logging.info("Setting up Ollama LLM...")
Settings.llm = Ollama(model="gemma:2b", request_timeout=120.0)
logging.info("Setting up Ollama Embedding...")

ollama_embedding = OllamaEmbedding(
    model_name="gemma:2b",
    base_url="http://localhost:11434",
    ollama_additional_kwargs={"mirostat": 0, "request_timeout": 120},
)
# Out:
# 2025-01-06 21:09:00,120 - root - INFO - Setting up Ollama LLM...
# 2025-01-06 21:09:00,124 - root - INFO - Setting up Ollama Embedding...

# %%
# 3. Create the index

# This can take some time
logging.info("Creating index...")
index = VectorStoreIndex.from_documents(documents, embed_model=ollama_embedding)
logging.info("Setting up index completed...")
# Out:
# 2025-01-06 21:09:08,972 - root - INFO - Creating index...
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~/AIcamp_LLM/lab_env/lib/python3.11/site-packages/httpx/_transports/default.py:72, in map_httpcore_exceptions()
#      71 try:
# ---> 72     yield
#      73 except Exception as exc:
#
# File ~/AIcamp_LLM/lab_env/lib/python3.11/site-packages/httpx/_transports/default.py:236, in HTTPTransport.handle_request(self, request)
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/AIcamp_LLM/lab_env/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File ~/AIcamp_LLM/lab_env/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File ~/AIcamp_LLM/lab_env/lib/python3.11/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File ~/AIcamp_LLM/lab_env/lib/python3.11/site-packages/httpcore/_sync/connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File ~/AIcamp_LLM/lab_env/lib/python3.11/site-packages/httpcore/_sync/connection.py:124, in HTTPConnection._connect(self, request)
#     123 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File ~/AIcamp_LLM/lab_env/lib/python3.11/site-packages/httpcore/_backends/sync.py:207, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     202 exc_map: ExceptionMapping = {
#     203     socket.timeout: ConnectTimeout,
#     204     OSError: ConnectError,
#     205 }
# --> 207 with map_exceptions(exc_map):
#     208     sock = socket.create_connection(
#     209         address,
#     210         timeout,
#     211         source_address=source_address,
#     212     )
#
# File /usr/lib/python3.11/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/AIcamp_LLM/lab_env/lib/python3.11/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# Cell In[10], line 5
#       1 # 3. Create the index
#       2
#       3 # This can take some time
#       4 logging.info("Creating index...")
# ----> 5 index = VectorStoreIndex.from_documents(documents, embed_model=ollama_embedding)
#       6 logging.info("Setting up index completed...")
#
# File ~/AIcamp_LLM/lab_env/lib/python3.11/site-packages/llama_index/core/indices/base.py:119, in BaseIndex.from_documents(cls, documents, storage_context, show_progress, callback_manager, transformations, **kwargs)
#     110     docstore.set_document_hash(doc.get_doc_id(), doc.hash)
#     112 nodes = run_transformations(
#     113     documents,  # type: ignore
#     114     transformations,
#     115     show_progress=show_progress,
#     116     **kwargs,
#     117 )
# --> 119 return cls(
#     120     nodes=nodes,
#     121     storage_context=storage_context,
#     122     callback_manager=callback_manager,
#     123     show_progress=show_progress,
#     124     transformations=transformations,
#     125     **kwargs,
#     126 )
#
# File ~/AIcamp_LLM/lab_env/lib/python3.11/site-packages/llama_index/core/indices/vector_store/base.py:76, in VectorStoreIndex.__init__(self, nodes, use_async, store_nodes_override, embed_model, insert_batch_size, objects, index_struct, storage_context, callback_manager, transformations, show_progress, **kwargs)
#      69 self._embed_model = (
#      70     resolve_embed_model(embed_model, callback_manager=callback_manager)
#      71     if embed_model
#      72     else Settings.embed_model
#      73 )
#      75 self._insert_batch_size = insert_batch_size
# ---> 76 super().__init__(
#      77     nodes=nodes,
#      78     index_struct=index_struct,
#      79     storage_context=storage_context,
#      80     show_progress=show_progress,
#      81     objects=objects,
#      82     callback_manager=callback_manager,
#      83     transformations=transformations,
#      84     **kwargs,
#      85 )
#
# File ~/AIcamp_LLM/lab_env/lib/python3.11/site-packages/llama_index/core/indices/base.py:77, in BaseIndex.__init__(self, nodes, objects, index_struct, storage_context, callback_manager, transformations, show_progress, **kwargs)
#      75 if index_struct is None:
#      76     nodes = nodes or []
# ---> 77     index_struct = self.build_index_from_nodes(
#      78         nodes + objects,  # type: ignore
#      79         **kwargs,  # type: ignore
#      80     )
#      81 self._index_struct = index_struct
#      82 self._storage_context.index_store.add_index_struct(self._index_struct)
#
# File ~/AIcamp_LLM/lab_env/lib/python3.11/site-packages/llama_index/core/indices/vector_store/base.py:310, in VectorStoreIndex.build_index_from_nodes(self, nodes, **insert_kwargs)
#     307 if len(content_nodes) != len(nodes):
#     308     print("Some nodes are missing content, skipping them...")
# --> 310 return self._build_index_from_nodes(content_nodes, **insert_kwargs)
#
# File ~/AIcamp_LLM/lab_env/lib/python3.11/site-packages/llama_index/core/indices/vector_store/base.py:279, in VectorStoreIndex._build_index_from_nodes(self, nodes, **insert_kwargs)
#     277     run_async_tasks(tasks)
#     278 else:
# --> 279     self._add_nodes_to_index(
#     280         index_struct,
#     281         nodes,
#     282         show_progress=self._show_progress,
#     283         **insert_kwargs,
#     284     )
#     285 return index_struct
#
# File ~/AIcamp_LLM/lab_env/lib/python3.11/site-packages/llama_index/core/indices/vector_store/base.py:232, in VectorStoreIndex._add_nodes_to_index(self, index_struct, nodes, show_progress, **insert_kwargs)
#     229     return
#     231 for nodes_batch in iter_batch(nodes, self._insert_batch_size):
# --> 232     nodes_batch = self._get_node_with_embedding(nodes_batch, show_progress)
#     233     new_ids = self._vector_store.add(nodes_batch, **insert_kwargs)
#     235     if not self._vector_store.stores_text or self._store_nodes_override:
#     236         # NOTE: if the vector store doesn't store text,
#     237         # we need to add the nodes to the index struct and document store
#
# File ~/AIcamp_LLM/lab_env/lib/python3.11/site-packages/llama_index/core/indices/vector_store/base.py:139, in VectorStoreIndex._get_node_with_embedding(self, nodes, show_progress)
#     127 def _get_node_with_embedding(
#     128     self,
#     129     nodes: Sequence[BaseNode],
#     130     show_progress: bool = False,
#     131 ) -> List[BaseNode]:
#     132     """
#     133     Get tuples of id, node, and embedding.
#     134
#    (...)
#     137
#     138     """
# --> 139     id_to_embed_map = embed_nodes(
#     140         nodes, self._embed_model, show_progress=show_progress
#     141     )
#     143     results = []
#     144     for node in nodes:
#
# File ~/AIcamp_LLM/lab_env/lib/python3.11/site-packages/llama_index/core/indices/utils.py:160, in embed_nodes(nodes, embed_model, show_progress)
#     157     else:
#     158         id_to_embed_map[node.node_id] = node.embedding
# --> 160 new_embeddings = embed_model.get_text_embedding_batch(
#     161     texts_to_embed, show_progress=show_progress
#     162 )
#     164 for new_id, text_embedding in zip(ids_to_embed, new_embeddings):
#     165     id_to_embed_map[new_id] = text_embedding
#
# File ~/AIcamp_LLM/lab_env/lib/python3.11/site-packages/llama_index/core/instrumentation/dispatcher.py:321, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     318             _logger.debug(f"Failed to reset active_span_id: {e}")
#     320 try:
# --> 321     result = func(*args, **kwargs)
#     322     if isinstance(result, asyncio.Future):
#     323         # If the result is a Future, wrap it
#     324         new_future = asyncio.ensure_future(result)
#
# File ~/AIcamp_LLM/lab_env/lib/python3.11/site-packages/llama_index/core/base/embeddings/base.py:335, in BaseEmbedding.get_text_embedding_batch(self, texts, show_progress, **kwargs)
#     326 dispatcher.event(
#     327     EmbeddingStartEvent(
#     328         model_dict=model_dict,
#     329     )
#     330 )
#     331 with self.callback_manager.event(
#     332     CBEventType.EMBEDDING,
#     333     payload={EventPayload.SERIALIZED: self.to_dict()},
#     334 ) as event:
# --> 335     embeddings = self._get_text_embeddings(cur_batch)
#     336     result_embeddings.extend(embeddings)
#     337     event.on_end(
#     338         payload={
#     339             EventPayload.CHUNKS: cur_batch,
#     340             EventPayload.EMBEDDINGS: embeddings,
#     341         },
#     342     )
#
# File ~/AIcamp_LLM/lab_env/lib/python3.11/site-packages/llama_index/embeddings/ollama/base.py:75, in OllamaEmbedding._get_text_embeddings(self, texts)
#      73 embeddings_list: List[List[float]] = []
#      74 for text in texts:
# ---> 75     embeddings = self.get_general_text_embedding(text)
#      76     embeddings_list.append(embeddings)
#      78 return embeddings_list
#
# File ~/AIcamp_LLM/lab_env/lib/python3.11/site-packages/llama_index/embeddings/ollama/base.py:88, in OllamaEmbedding.get_general_text_embedding(self, texts)
#      86 def get_general_text_embedding(self, texts: str) -> List[float]:
#      87     """Get Ollama embedding."""
# ---> 88     result = self._client.embeddings(
#      89         model=self.model_name, prompt=texts, options=self.ollama_additional_kwargs
#      90     )
#      91     return result["embedding"]
#
# File ~/AIcamp_LLM/lab_env/lib/python3.11/site-packages/ollama/_client.py:379, in Client.embeddings(self, model, prompt, options, keep_alive)
#     369 def embeddings(
#     370   self,
#     371   model: str = '',
#    (...)
#     374   keep_alive: Optional[Union[float, str]] = None,
#     375 ) -> EmbeddingsResponse:
#     376   """
#     377   Deprecated in favor of `embed`.
#     378   """
# --> 379   return self._request(
#     380     EmbeddingsResponse,
#     381     'POST',
#     382     '/api/embeddings',
#     383     json=EmbeddingsRequest(
#     384       model=model,
#     385       prompt=prompt,
#     386       options=options,
#     387       keep_alive=keep_alive,
#     388     ).model_dump(exclude_none=True),
#     389   )
#
# File ~/AIcamp_LLM/lab_env/lib/python3.11/site-packages/ollama/_client.py:177, in Client._request(self, cls, stream, *args, **kwargs)
#     173         yield cls(**part)
#     175   return inner()
# --> 177 return cls(**self._request_raw(*args, **kwargs).json())
#
# File ~/AIcamp_LLM/lab_env/lib/python3.11/site-packages/ollama/_client.py:118, in Client._request_raw(self, *args, **kwargs)
#     117 def _request_raw(self, *args, **kwargs):
# --> 118   r = self._client.request(*args, **kwargs)
#     119   try:
#     120     r.raise_for_status()
#
# File ~/AIcamp_LLM/lab_env/lib/python3.11/site-packages/httpx/_client.py:837, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     822     warnings.warn(message, DeprecationWarning)
#     824 request = self.build_request(
#     825     method=method,
#     826     url=url,
#    (...)
#     835     extensions=extensions,
#     836 )
# --> 837 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/AIcamp_LLM/lab_env/lib/python3.11/site-packages/httpx/_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     922 self._set_timeout(request)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#     933     if not stream:
#
# File ~/AIcamp_LLM/lab_env/lib/python3.11/site-packages/httpx/_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     951 request = next(auth_flow)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#     960         try:
#
# File ~/AIcamp_LLM/lab_env/lib/python3.11/site-packages/httpx/_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     988 for hook in self._event_hooks["request"]:
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#     993     for hook in self._event_hooks["response"]:
#
# File ~/AIcamp_LLM/lab_env/lib/python3.11/site-packages/httpx/_client.py:1027, in Client._send_single_request(self, request)
#    1022     raise RuntimeError(
#    1023         "Attempted to send an async request with a sync Client instance."
#    1024     )
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#    1031 response.request = request
#
# File ~/AIcamp_LLM/lab_env/lib/python3.11/site-packages/httpx/_transports/default.py:235, in HTTPTransport.handle_request(self, request)
#     221 assert isinstance(request.stream, SyncByteStream)
#     223 req = httpcore.Request(
#     224     method=request.method,
#     225     url=httpcore.URL(
#    (...)
#     233     extensions=request.extensions,
#     234 )
# --> 235 with map_httpcore_exceptions():
#     236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#
# File /usr/lib/python3.11/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     156     value = typ()
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#     163     return exc is not value
#
# File ~/AIcamp_LLM/lab_env/lib/python3.11/site-packages/httpx/_transports/default.py:89, in map_httpcore_exceptions()
#      86     raise
#      88 message = str(exc)
# ---> 89 raise mapped_exc(message) from exc
#
# ConnectError: [Errno 111] Connection refused

# %%
# 4. Query the index

#This will take more than a minute as well on IDX
logging.info("Querying index...")
query_engine = index.as_query_engine()

sitrep = query_engine.query("Scarecrow?")
print(sitrep)
# Out:
# 2025-01-02 13:39:07,631 - root - INFO - Querying index...
# 2025-01-02 13:39:08,285 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/embeddings "HTTP/1.1 200 OK"
# 2025-01-02 13:40:17,490 - httpx - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# The context does not provide information about Scarecrow, so I cannot answer this query from the provided context.
